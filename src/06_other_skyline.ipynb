# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from plot_rides import plot_rides_by_day, plot_rides_by_hour, plot_rides_by_month,plot_rides_by_day_of_month
import seaborn as sns
from extract_data import extract_hour_day_month

# %%
data = pd.read_csv('../data/other-Skyline_B00111.csv')

# %%
data
# Out:
#              Date            Time                   Street_Address   \
# 0        7/1/2014      20:27           622 THIRD AV
# 1        7/1/2014      21:04            E 77TH ST
# 2        7/1/2014      22:20           67 WEST PALISADES BLVD
# 3        7/1/2014      12:28           130 MIDDLE NECK RD
# 4        7/1/2014      16:45           36 E 31ST ST
# ...           ...             ...                               ...
# 127691  9/29/2014      13:15           370 7th AVE
# 127692  9/29/2014      15:40           1 STATE ST PZ
# 127693  9/29/2014      20:07           730 5TH AVE
# 127694  9/29/2014      22:48           30 ROCKEFELLER PZ
# 127695  9/29/2014      16:00           904 LEXINGTON AV
#
#                           City_State   Unnamed: 4  Unnamed: 5
# 0            M                                NaN         NaN
# 1            M                                NaN         NaN
# 2           PALISADES PARK NJ                 NaN         NaN
# ...

# %%
data.describe(include='all')
# Out:
#              Date            Time                   Street_Address   \
# count      127696          127696                            127696
# unique         92            1440                             24463
# top     9/16/2014      09:40
# freq         2230            1389                             10622
# mean          NaN             NaN                               NaN
# std           NaN             NaN                               NaN
# min           NaN             NaN                               NaN
# 25%           NaN             NaN                               NaN
# 50%           NaN             NaN                               NaN
# 75%           NaN             NaN                               NaN
# max           NaN             NaN                               NaN
#
#                           City_State   Unnamed: 4  Unnamed: 5
# count                          127696         0.0         0.0
# unique                            704         NaN         NaN
# ...

# %%
data = data.drop(['Unnamed: 4', 'Unnamed: 5'], axis=1)

# %%
data
# Out:
#              Date            Time                   Street_Address   \
# 0        7/1/2014      20:27           622 THIRD AV
# 1        7/1/2014      21:04            E 77TH ST
# 2        7/1/2014      22:20           67 WEST PALISADES BLVD
# 3        7/1/2014      12:28           130 MIDDLE NECK RD
# 4        7/1/2014      16:45           36 E 31ST ST
# ...           ...             ...                               ...
# 127691  9/29/2014      13:15           370 7th AVE
# 127692  9/29/2014      15:40           1 STATE ST PZ
# 127693  9/29/2014      20:07           730 5TH AVE
# 127694  9/29/2014      22:48           30 ROCKEFELLER PZ
# 127695  9/29/2014      16:00           904 LEXINGTON AV
#
#                           City_State
# 0            M
# 1            M
# 2           PALISADES PARK NJ
# 3           SANDS POINT LI
# 4            M
# ...                               ...
# 127691       M
# 127692       M
# 127693       M
# 127694       M
# 127695       M
#
# ...

# %%
data.describe(include='all')
# Out:
#              Date            Time                   Street_Address   \
# count      127696          127696                            127696
# unique         92            1440                             24463
# top     9/16/2014      09:40
# freq         2230            1389                             10622
#
#                           City_State
# count                          127696
# unique                            704
# top          M
# freq                            71207

# %%
np.unique(data['    Street_Address '])
# Out:
# array(['                                ',
#        '     .                          ',
#        '     ....                       ', ..., '1', '289', '610'],
#       dtype=object)

# %%
np.unique(data['    City_State '])
# Out:
# array(['                             ', '     BDL                     ',
#        '     BK                      ', '     BX                      ',
#        '     JFK                     ', '     LAG                     ',
#        '     M                       ', '     MCA                     ',
#        '     NBG                     ', '     NWK                     ',
#        '     QU                      ', '     SI                      ',
#        '     TTB                     ', '     WEA                     ',
#        '    ALLENDALE NJ             ', '    ALPINE NJ                ',
#        '    AMAGANSETT LI            ', '    AMENIA NY                ',
#        '    AMITYVILLE LI            ', '    ANDOVER NJ               ',
#        '    ANNANDALE NJ             ', '    ARDSLEY WE               ',
#        '    ARMONK WE                ', '    ARTIFICIAL KIDNEY CT QU  ',
#        '    ASBURY PARK NJ           ', '    ASIAN ELDER M            ',
# ...

# %%
data
# Out:
#              Date            Time                   Street_Address   \
# 0        7/1/2014      20:27           622 THIRD AV
# 1        7/1/2014      21:04            E 77TH ST
# 2        7/1/2014      22:20           67 WEST PALISADES BLVD
# 3        7/1/2014      12:28           130 MIDDLE NECK RD
# 4        7/1/2014      16:45           36 E 31ST ST
# ...           ...             ...                               ...
# 127691  9/29/2014      13:15           370 7th AVE
# 127692  9/29/2014      15:40           1 STATE ST PZ
# 127693  9/29/2014      20:07           730 5TH AVE
# 127694  9/29/2014      22:48           30 ROCKEFELLER PZ
# 127695  9/29/2014      16:00           904 LEXINGTON AV
#
#                           City_State
# 0            M
# 1            M
# 2           PALISADES PARK NJ
# 3           SANDS POINT LI
# 4            M
# ...                               ...
# 127691       M
# 127692       M
# 127693       M
# 127694       M
# 127695       M
#
# ...

# %%
data['Date/Time'] = pd.to_datetime(data['Date'].str.strip() + ' ' + data['Time'].str.strip(), format='%m/%d/%Y %H:%M')

# %%
data.drop(['Date','Time'],axis=1)
# Out:
#                          Street_Address                     City_State   \
# 0           622 THIRD AV                       M
# 1            E 77TH ST                         M
# 2           67 WEST PALISADES BLVD            PALISADES PARK NJ
# 3           130 MIDDLE NECK RD                SANDS POINT LI
# 4           36 E 31ST ST                       M
# ...                                  ...                            ...
# 127691      370 7th AVE                        M
# 127692      1 STATE ST PZ                      M
# 127693      730 5TH AVE                        M
# 127694      30 ROCKEFELLER PZ                  M
# 127695      904 LEXINGTON AV                   M
#
#                  Date/Time
# 0      2014-07-01 20:27:00
# 1      2014-07-01 21:04:00
# 2      2014-07-01 22:20:00
# 3      2014-07-01 12:28:00
# 4      2014-07-01 16:45:00
# ...                    ...
# 127691 2014-09-29 13:15:00
# 127692 2014-09-29 15:40:00
# 127693 2014-09-29 20:07:00
# ...

# %%
extract_hour_day_month(data)

# %%
data
# Out:
#              Date            Time                   Street_Address   \
# 0        7/1/2014      20:27           622 THIRD AV
# 1        7/1/2014      21:04            E 77TH ST
# 2        7/1/2014      22:20           67 WEST PALISADES BLVD
# 3        7/1/2014      12:28           130 MIDDLE NECK RD
# 4        7/1/2014      16:45           36 E 31ST ST
# ...           ...             ...                               ...
# 127691  9/29/2014      13:15           370 7th AVE
# 127692  9/29/2014      15:40           1 STATE ST PZ
# 127693  9/29/2014      20:07           730 5TH AVE
# 127694  9/29/2014      22:48           30 ROCKEFELLER PZ
# 127695  9/29/2014      16:00           904 LEXINGTON AV
#
#                           City_State            Date/Time  Hour      Month  \
# 0            M                        2014-07-01 20:27:00    20       July
# 1            M                        2014-07-01 21:04:00    21       July
# ...

# %%
month_order = ['July','August','September']

# %%
plot_rides_by_month(data,month_order)
# Out:
# Month
# July         42277
# August       39080
# September    46339
# Name: count, dtype: int64

# %% [markdown]
# For Skyline we have data for July-September of 2014. For all three months there is simmilar amount of data.

# %%
plot_rides_by_day(data)

# %% [markdown]
# Different distribution of data between days of week, comparing to Uber. A lot less rides on weekends that on workdays.

# %%
plot_rides_by_hour(data)

# %% [markdown]
# Difference in distribution comparing to both uber in 2014 and 2015. Peek is between 20-21h comparing to 17-18h in Uber, here we can see that for Skylift around 18h we have lot less rides that to surounding hours, where in Uber 18h was peek. Also there is no signifficant decline in pickup number between 9-16h.

# %%
plot_rides_by_day_of_month(data)
